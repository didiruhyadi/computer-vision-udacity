# %% [markdown]
# <a href="https://colab.research.google.com/github/didiruhyadi/computer-vision/blob/main/2A_L1_Image_as_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this is lesson number 2

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
print("OpenCV version :",cv2.__version__)
# Out:
# OpenCV version : 4.1.2

# %%
# display image using opencv
image = cv2.imread('/content/sample_data/Udacity Computer Vision/dolphin.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.title("Dolphin")

print("Image Shape :", image.shape)
print("Image type :", image.dtype)
print(image[:].shape)
# Out:
# Image Shape : (412, 330, 3)
# Image type : uint8
# (412, 330, 3)

# %%
#Inspect image value using histogram

#using cv2
image = cv2.imread('/content/sample_data/Udacity Computer Vision/dolphin.jpg')
hist = cv2.calcHist([image],[0],None,[256],[0,256])
plt.figure()
plt.plot(hist)
plt.title("Histogram using OpenCV")
plt.ylabel("Numb. of Pixel")
plt.xlabel("Pixel Value")
plt.show()

#using matplotlib
plt.figure()
plt.hist(image.ravel(), 256, [0, 256])
plt.title("Histogram using Matplotlib")
plt.ylabel("Numb. of Pixel")
plt.xlabel("Pixel Value")
plt.show()

# %%
#Inspect image value
image = image[50:250, 50:250, :]
plt.imshow(image)
